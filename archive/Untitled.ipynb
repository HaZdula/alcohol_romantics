# %%
import numpy as np
import pandas as pd
import seaborn as sns
import category_encoders as ce
import xgboost as xgb
pd.options.display.max_columns = None

# %%
df_0 = pd.read_csv('./students-all.csv')
df_0 = df_0.drop(columns='Unnamed: 0')

# %%
df = df_0.copy()
df['romantic'] = np.where(df['romantic']=='yes', 1, 0)
y = df[['romantic']]
X = df.drop(columns='romantic')
X.head(5)
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher
# 1     GP   F   17       U     GT3       T     1     1  at_home     other
# 2     GP   F   15       U     LE3       T     1     1  at_home     other
# 3     GP   F   15       U     GT3       T     4     2   health  services
# 4     GP   F   16       U     GT3       T     3     3    other     other
#
#    reason guardian  traveltime  studytime  failures schoolsup famsup paid  \
# 0  course   mother           2          2         0       yes     no   no
# 1  course   father           1          2         0        no    yes   no
# 2   other   mother           1          2         3       yes     no  yes
# 3    home   mother           1          3         0        no    yes  yes
# 4    home   father           1          2         0        no    yes  yes
#
#   activities nursery higher internet  famrel  freetime  goout  Dalc  Walc  \
# 0         no     yes    yes       no       4         3      4     1     1
# 1         no      no    yes      yes       5         3      3     1     1
# 2         no     yes    yes      yes       4         3      2     2     3
# 3        yes     yes    yes      yes       3         2      2     1     1
# 4         no     yes    yes       no       4         3      2     1     2
#
#    health  absences  G1  G2  G3 major
# 0       3         6   5   6   6   mat
# 1       3         4   5   5   6   mat
# 2       3        10   7   8  10   mat
# 3       5         2  15  14  15   mat
# 4       5         4   6  10  10   mat

# %%
encoder = ce.HelmertEncoder(cols =['school', 'sex', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
       'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
       'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
       'higher', 'internet', 'famrel', 'freetime', 'goout', 'Dalc',
       'health', 'major'])

# %%
df_encoded = encoder.fit_transform(df)
df_encoded.columns
# Out:
# Index(['intercept', 'school_0', 'sex_0', 'age', 'address_0', 'famsize_0',
#        'Pstatus_0', 'Medu_0', 'Medu_1', 'Medu_2', 'Medu_3', 'Fedu_0', 'Fedu_1',
#        'Fedu_2', 'Fedu_3', 'Mjob_0', 'Mjob_1', 'Mjob_2', 'Mjob_3', 'Fjob_0',
#        'Fjob_1', 'Fjob_2', 'Fjob_3', 'reason_0', 'reason_1', 'reason_2',
#        'guardian_0', 'guardian_1', 'traveltime_0', 'traveltime_1',
#        'traveltime_2', 'studytime_0', 'studytime_1', 'studytime_2',
#        'failures_0', 'failures_1', 'failures_2', 'schoolsup_0', 'famsup_0',
#        'paid_0', 'activities_0', 'nursery_0', 'higher_0', 'internet_0',
#        'romantic', 'famrel_0', 'famrel_1', 'famrel_2', 'famrel_3',
#        'freetime_0', 'freetime_1', 'freetime_2', 'freetime_3', 'goout_0',
#        'goout_1', 'goout_2', 'goout_3', 'Dalc_0', 'Dalc_1', 'Dalc_2', 'Dalc_3',
#        'Walc', 'health_0', 'health_1', 'health_2', 'health_3', 'absences',
#        'G1', 'G2', 'G3', 'major_0'],
#       dtype='object')

# %%
def train_fast(df):
    
    df = df.sample(frac=1).reset_index(drop=True)
    train = df.iloc[1:round(0.7*len(df)),:]
    validation = df.iloc[round(0.7*len(df)):round(0.85*len(df)),:]
    test = df.iloc[round(0.85*len(df)):,:]
    label_train = train.romantic
    label_val = validation.romantic
    label_test = test.romantic

    df_train = train.drop(["romantic"], axis = 1)
    df_test  = test.drop(["romantic"], axis = 1)
    df_val  = validation.drop(["romantic"], axis = 1)
    dtrain = xgb.DMatrix(data = df_train, label=label_train)
    dval = xgb.DMatrix(data = df_val, label=label_val)
    dtest = xgb.DMatrix(data = df_test, label=label_val)
    param = {'max_depth': 12, 'eta': 1, 'objective': 'binary:logistic', 'eval_metric':'ndcg'}
    evallist = [(dval, 'eval'), (dtrain, 'train')]
    num_round = 200
    bst = xgb.train(param, dtrain, num_round, evallist)
    ypred = bst.predict(dtest, ntree_limit=bst.best_ntree_limit)
    ret = sum(np.round(ypred) == label_test)/label_test.size
    
    return ret, bst

# %%
acc , bst = train_fast(df_dummy)
# Out:
# [0]	eval-ndcg:0.74373	train-ndcg:0.98381
# [1]	eval-ndcg:0.78749	train-ndcg:0.99824
# [2]	eval-ndcg:0.82278	train-ndcg:0.99986
# [3]	eval-ndcg:0.83140	train-ndcg:0.99999
# [4]	eval-ndcg:0.81082	train-ndcg:1.00000
# [5]	eval-ndcg:0.87302	train-ndcg:1.00000
# [6]	eval-ndcg:0.87764	train-ndcg:1.00000
# [7]	eval-ndcg:0.87545	train-ndcg:1.00000
# [8]	eval-ndcg:0.87371	train-ndcg:1.00000
# [9]	eval-ndcg:0.86285	train-ndcg:1.00000
# [10]	eval-ndcg:0.86408	train-ndcg:1.00000
# [11]	eval-ndcg:0.87232	train-ndcg:1.00000
# [12]	eval-ndcg:0.87412	train-ndcg:1.00000
# [13]	eval-ndcg:0.87433	train-ndcg:1.00000
# [14]	eval-ndcg:0.87592	train-ndcg:1.00000
# [15]	eval-ndcg:0.88086	train-ndcg:1.00000
# [16]	eval-ndcg:0.88491	train-ndcg:1.00000
# [17]	eval-ndcg:0.88780	train-ndcg:1.00000
# [18]	eval-ndcg:0.88866	train-ndcg:1.00000
# [19]	eval-ndcg:0.89061	train-ndcg:1.00000
# [20]	eval-ndcg:0.89009	train-ndcg:1.00000
# [21]	eval-ndcg:0.89001	train-ndcg:1.00000
# [22]	eval-ndcg:0.88634	train-ndcg:1.00000
# [23]	eval-ndcg:0.88671	train-ndcg:1.00000
# [24]	eval-ndcg:0.88642	train-ndcg:1.00000
# [25]	eval-ndcg:0.88539	train-ndcg:1.00000
# [26]	eval-ndcg:0.88916	train-ndcg:1.00000
# [27]	eval-ndcg:0.89204	train-ndcg:1.00000
# [28]	eval-ndcg:0.89239	train-ndcg:1.00000
# [29]	eval-ndcg:0.89241	train-ndcg:1.00000
# [30]	eval-ndcg:0.89369	train-ndcg:1.00000
# [31]	eval-ndcg:0.89546	train-ndcg:1.00000
# [32]	eval-ndcg:0.89443	train-ndcg:1.00000
# [33]	eval-ndcg:0.89326	train-ndcg:1.00000
# [34]	eval-ndcg:0.89202	train-ndcg:1.00000
# [35]	eval-ndcg:0.89228	train-ndcg:1.00000
# [36]	eval-ndcg:0.89070	train-ndcg:1.00000
# [37]	eval-ndcg:0.88940	train-ndcg:1.00000
# [38]	eval-ndcg:0.88706	train-ndcg:1.00000
# [39]	eval-ndcg:0.88537	train-ndcg:1.00000
# [40]	eval-ndcg:0.89069	train-ndcg:1.00000
# [41]	eval-ndcg:0.89217	train-ndcg:1.00000
# [42]	eval-ndcg:0.88772	train-ndcg:1.00000
# [43]	eval-ndcg:0.89299	train-ndcg:1.00000
# [44]	eval-ndcg:0.88990	train-ndcg:1.00000
# [45]	eval-ndcg:0.88892	train-ndcg:1.00000
# [46]	eval-ndcg:0.88806	train-ndcg:1.00000
# [47]	eval-ndcg:0.88970	train-ndcg:1.00000
# [48]	eval-ndcg:0.88923	train-ndcg:1.00000
# [49]	eval-ndcg:0.88731	train-ndcg:1.00000
# [156]	eval-ndcg:0.88580	train-ndcg:1.00000
# [157]	eval-ndcg:0.88611	train-ndcg:1.00000
# [158]	eval-ndcg:0.88575	train-ndcg:1.00000
# [159]	eval-ndcg:0.88608	train-ndcg:1.00000
# [160]	eval-ndcg:0.88609	train-ndcg:1.00000
# [161]	eval-ndcg:0.88616	train-ndcg:1.00000
# [162]	eval-ndcg:0.88655	train-ndcg:1.00000
# [163]	eval-ndcg:0.88617	train-ndcg:1.00000
# [164]	eval-ndcg:0.88580	train-ndcg:1.00000
# [165]	eval-ndcg:0.88540	train-ndcg:1.00000
# [166]	eval-ndcg:0.88609	train-ndcg:1.00000
# [167]	eval-ndcg:0.88605	train-ndcg:1.00000
# [168]	eval-ndcg:0.88637	train-ndcg:1.00000
# [169]	eval-ndcg:0.88610	train-ndcg:1.00000
# [170]	eval-ndcg:0.88601	train-ndcg:1.00000
# [171]	eval-ndcg:0.88604	train-ndcg:1.00000
# [172]	eval-ndcg:0.88660	train-ndcg:1.00000
# [173]	eval-ndcg:0.88577	train-ndcg:1.00000
# [174]	eval-ndcg:0.88624	train-ndcg:1.00000
# [175]	eval-ndcg:0.88559	train-ndcg:1.00000
# [176]	eval-ndcg:0.88526	train-ndcg:1.00000
# [177]	eval-ndcg:0.88513	train-ndcg:1.00000
# [178]	eval-ndcg:0.88574	train-ndcg:1.00000
# [179]	eval-ndcg:0.88535	train-ndcg:1.00000
# [180]	eval-ndcg:0.88549	train-ndcg:1.00000
# [181]	eval-ndcg:0.88482	train-ndcg:1.00000
# [182]	eval-ndcg:0.88557	train-ndcg:1.00000
# [183]	eval-ndcg:0.88570	train-ndcg:1.00000
# [184]	eval-ndcg:0.88577	train-ndcg:1.00000
# [185]	eval-ndcg:0.88542	train-ndcg:1.00000
# [186]	eval-ndcg:0.88536	train-ndcg:1.00000
# [187]	eval-ndcg:0.88614	train-ndcg:1.00000
# [188]	eval-ndcg:0.88617	train-ndcg:1.00000
# [189]	eval-ndcg:0.88620	train-ndcg:1.00000
# [190]	eval-ndcg:0.88469	train-ndcg:1.00000
# [191]	eval-ndcg:0.88403	train-ndcg:1.00000
# [192]	eval-ndcg:0.88424	train-ndcg:1.00000
# [193]	eval-ndcg:0.88437	train-ndcg:1.00000
# [194]	eval-ndcg:0.88456	train-ndcg:1.00000
# [195]	eval-ndcg:0.88441	train-ndcg:1.00000
# [196]	eval-ndcg:0.88499	train-ndcg:1.00000
# [197]	eval-ndcg:0.88512	train-ndcg:1.00000
# [198]	eval-ndcg:0.88531	train-ndcg:1.00000
# [199]	eval-ndcg:0.88509	train-ndcg:1.00000

# %%
acc
# Out:
# 0.7579617834394905

# %%
df = pd.get_dummies(df_0, drop_first=True)

# %%
def train_fast(df):
    
    df = df.sample(frac=1).reset_index(drop=True)
    train = df.iloc[1:round(0.7*len(df)),:]
    validation = df.iloc[round(0.7*len(df)):round(0.85*len(df)),:]
    test = df.iloc[round(0.85*len(df)):,:]
    label_train = train.romantic_yes
    label_val = validation.romantic_yes
    label_test = test.romantic_yes

    df_train = train.drop(["romantic_yes"], axis = 1)
    df_test  = test.drop(["romantic_yes"], axis = 1)
    df_val  = validation.drop(["romantic_yes"], axis = 1)
    dtrain = xgb.DMatrix(data = df_train, label=label_train)
    dval = xgb.DMatrix(data = df_val, label=label_val)
    dtest = xgb.DMatrix(data = df_test, label=label_val)
    param = {'max_depth': 12, 'eta': 1, 'objective': 'binary:logistic', 'eval_metric':'ndcg'}
    evallist = [(dval, 'eval'), (dtrain, 'train')]
    num_round = 200
    bst = xgb.train(param, dtrain, num_round, evallist)
    ypred = bst.predict(dtest, ntree_limit=bst.best_ntree_limit)
    ret = sum(np.round(ypred) == label_test)/label_test.size
    
    return ret, bst

acc , bst = train_fast(df)
acc
# Out:
# [0]	eval-ndcg:0.86535	train-ndcg:0.97971
# [1]	eval-ndcg:0.89491	train-ndcg:0.99571
# [2]	eval-ndcg:0.83925	train-ndcg:0.99916
# [3]	eval-ndcg:0.88733	train-ndcg:0.99993
# [4]	eval-ndcg:0.88908	train-ndcg:1.00000
# [5]	eval-ndcg:0.88620	train-ndcg:1.00000
# [6]	eval-ndcg:0.89407	train-ndcg:1.00000
# [7]	eval-ndcg:0.89961	train-ndcg:1.00000
# [8]	eval-ndcg:0.91051	train-ndcg:1.00000
# [9]	eval-ndcg:0.90777	train-ndcg:1.00000
# [10]	eval-ndcg:0.90282	train-ndcg:1.00000
# [11]	eval-ndcg:0.90298	train-ndcg:1.00000
# [12]	eval-ndcg:0.91389	train-ndcg:1.00000
# [13]	eval-ndcg:0.90937	train-ndcg:1.00000
# [14]	eval-ndcg:0.90721	train-ndcg:1.00000
# [15]	eval-ndcg:0.91354	train-ndcg:1.00000
# [16]	eval-ndcg:0.90805	train-ndcg:1.00000
# [17]	eval-ndcg:0.90704	train-ndcg:1.00000
# [18]	eval-ndcg:0.90388	train-ndcg:1.00000
# [19]	eval-ndcg:0.90206	train-ndcg:1.00000
# [20]	eval-ndcg:0.90673	train-ndcg:1.00000
# [21]	eval-ndcg:0.89741	train-ndcg:1.00000
# [22]	eval-ndcg:0.89532	train-ndcg:1.00000
# [23]	eval-ndcg:0.90660	train-ndcg:1.00000
# [24]	eval-ndcg:0.90608	train-ndcg:1.00000
# [25]	eval-ndcg:0.90248	train-ndcg:1.00000
# [26]	eval-ndcg:0.90277	train-ndcg:1.00000
# [27]	eval-ndcg:0.90437	train-ndcg:1.00000
# [28]	eval-ndcg:0.90233	train-ndcg:1.00000
# [29]	eval-ndcg:0.90516	train-ndcg:1.00000
# [30]	eval-ndcg:0.90293	train-ndcg:1.00000
# [31]	eval-ndcg:0.90356	train-ndcg:1.00000
# [32]	eval-ndcg:0.90369	train-ndcg:1.00000
# [33]	eval-ndcg:0.89123	train-ndcg:1.00000
# [34]	eval-ndcg:0.89187	train-ndcg:1.00000
# [35]	eval-ndcg:0.89508	train-ndcg:1.00000
# [36]	eval-ndcg:0.89139	train-ndcg:1.00000
# [37]	eval-ndcg:0.89375	train-ndcg:1.00000
# [38]	eval-ndcg:0.89483	train-ndcg:1.00000
# [39]	eval-ndcg:0.89641	train-ndcg:1.00000
# [40]	eval-ndcg:0.89374	train-ndcg:1.00000
# [41]	eval-ndcg:0.88521	train-ndcg:1.00000
